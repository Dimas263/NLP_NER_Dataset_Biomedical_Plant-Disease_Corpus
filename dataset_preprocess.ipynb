# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **BIO Dataset**

# %%
bio_dataset = open("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/BIO/final-data.txt", "r")
print(bio_dataset.read())
# Out:
# studies	O
# on	O
# magnesium s	O
# mechanism	O
# of	O
# action	O
# in	O
# digitalis	B-plant
# induced	O
# arrhythmias	B-disease
#
# the	O
# mechanism	O
# by	O
# which	O
# magnesium	O
# affects	O
# digitalis	B-plant
# induced	O
# arrhythmias	B-disease
# was	O
# studied	O
# in	O
# dogs	O
# with	O
# and	O
# without	O
# beta receptor	O
#
# magnesium s	O
# direct	O
# effect	O
# on	O
# calcium	O
# and	O
# potassium	O
# fluxes	O
# across	O
# the	O
# myocardial	O
# cell	O
# membrane	O
# may	O
# be	O
# the	O
# mechanism	O
# of	O
# its	O
# antiarrhythmic	O
# action	O
# in	O
# digitalis	B-plant
# toxic	O
# arrhythmias	B-disease
#
# inhibitory	O
# effect	O
# of	O
# green	B-plant
# tea	I-plant
# on	O
# the	O
# growth	O
# of	O
# established	O
# skin	B-disease
# papillomas	I-disease
# in	O
#
# in	O
# 10	O
# separate	O
# experiments	O
# mice	O
# with	O
# established	O
# chemically	O
# induced	O
# or	O
# uv	O
# light induced	O
# skin	B-disease
# papillomas	I-disease
# were	O
# treated	O
# ...

# %% [markdown]
# # **JSON Dataset**

# %%
import json

ner_json_dataset = open("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/excel_data/NER Dataset/ner_dataset.json", "r")
json.load(ner_json_dataset)
# Out:
# [{'id': 0,
#   'labels': [['T0', 'plant', 46, 55, 'digitalis'],
#    ['T1', 'disease', 64, 75, 'arrhythmias']],
#   'text': 'studies on magnesium s mechanism of action in digitalis induced arrhythmias'},
#  {'id': 1,
#   'labels': [['T0', 'plant', 41, 50, 'digitalis'],
#    ['T1', 'disease', 59, 70, 'arrhythmias']],
#   'text': 'the mechanism by which magnesium affects digitalis induced arrhythmias was studied in dogs with and without beta receptor'},
#  {'id': 2,
#   'labels': [['T0', 'plant', 147, 156, 'digitalis'],
#    ['T1', 'disease', 163, 174, 'arrhythmias']],
#   'text': 'magnesium s direct effect on calcium and potassium fluxes across the myocardial cell membrane may be the mechanism of its antiarrhythmic action in digitalis toxic arrhythmias'},
#  {'id': 3,
#   'labels': [['T0', 'plant', 21, 26, 'green'],
#    ['T1', 'plant', 27, 30, 'tea'],
#    ['T2', 'disease', 60, 64, 'skin'],
#    ['T3', 'disease', 65, 75, 'papillomas']],
# ...

# %% [markdown]
# # **JSON Dataset B-I-O**

# %%
ner_json_biodataset = open("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/excel_data/BIO NER Dataset/ner_dataset.json", "r")
json.load(ner_json_biodataset)
# Out:
# [{'id': 0,
#   'labels': [['T0', 'B-plant', 46, 55, 'digitalis'],
#    ['T1', 'B-disease', 64, 75, 'arrhythmias']],
#   'text': 'studies on magnesium s mechanism of action in digitalis induced arrhythmias'},
#  {'id': 1,
#   'labels': [['T0', 'B-plant', 41, 50, 'digitalis'],
#    ['T1', 'B-disease', 59, 70, 'arrhythmias']],
#   'text': 'the mechanism by which magnesium affects digitalis induced arrhythmias was studied in dogs with and without beta receptor'},
#  {'id': 2,
#   'labels': [['T0', 'B-plant', 147, 156, 'digitalis'],
#    ['T1', 'B-disease', 163, 174, 'arrhythmias']],
#   'text': 'magnesium s direct effect on calcium and potassium fluxes across the myocardial cell membrane may be the mechanism of its antiarrhythmic action in digitalis toxic arrhythmias'},
#  {'id': 3,
#   'labels': [['T0', 'B-plant', 21, 26, 'green'],
#    ['T1', 'I-plant', 27, 30, 'tea'],
#    ['T2', 'B-disease', 60, 64, 'skin'],
#    ['T3', 'I-disease', 65, 75, 'papillomas']],
# ...

# %% [markdown]
# # **EXCEL Dataset**

# %%
import pandas as pd

pd.read_excel("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/excel_data/NER Dataset/ner_dataset.xlsx").head(20)
# Out:
#      Sentence #         Word  POS      Tag
# 0   Sentence: 0      studies  NNS        O
# 1   Sentence: 0           on   IN        O
# 2   Sentence: 0    magnesium   NN        O
# 3   Sentence: 0            s   NN        O
# 4   Sentence: 0    mechanism   NN        O
# 5   Sentence: 0           of   IN        O
# 6   Sentence: 0       action   NN        O
# 7   Sentence: 0           in   IN        O
# 8   Sentence: 0    digitalis   NN    plant
# 9   Sentence: 0      induced  VBD        O
# 10  Sentence: 0  arrhythmias  NNS  disease
# 11  Sentence: 1          the   DT        O
# 12  Sentence: 1    mechanism   NN        O
# 13  Sentence: 1           by   IN        O
# 14  Sentence: 1        which  WDT        O
# 15  Sentence: 1    magnesium   NN        O
# 16  Sentence: 1      affects  VBZ        O
# 17  Sentence: 1    digitalis   RB    plant
# 18  Sentence: 1      induced   JJ        O
# 19  Sentence: 1  arrhythmias   NN  disease

# %% [markdown]
# # **EXCEL Dataset B-I-O**

# %%
import pandas as pd

pd.read_excel("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/excel_data/BIO NER Dataset/ner_dataset.xlsx").head(20)
# Out:
#      Sentence #         Word  POS        Tag
# 0   Sentence: 0      studies  NNS          O
# 1   Sentence: 0           on   IN          O
# 2   Sentence: 0    magnesium   NN          O
# 3   Sentence: 0            s   NN          O
# 4   Sentence: 0    mechanism   NN          O
# 5   Sentence: 0           of   IN          O
# 6   Sentence: 0       action   NN          O
# 7   Sentence: 0           in   IN          O
# 8   Sentence: 0    digitalis   NN    B-plant
# 9   Sentence: 0      induced  VBD          O
# 10  Sentence: 0  arrhythmias  NNS  B-disease
# 11  Sentence: 1          the   DT          O
# 12  Sentence: 1    mechanism   NN          O
# 13  Sentence: 1           by   IN          O
# 14  Sentence: 1        which  WDT          O
# 15  Sentence: 1    magnesium   NN          O
# 16  Sentence: 1      affects  VBZ          O
# 17  Sentence: 1    digitalis   RB    B-plant
# 18  Sentence: 1      induced   JJ          O
# 19  Sentence: 1  arrhythmias   NN  B-disease

# %% [markdown]
# # **CSV Dataset**

# %%
import csv
import pandas as pd

pd.read_csv("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/csv_data/ner_dataset.csv").head(20)
# Out:
#      Sentence #         Word  POS      Tag
# 0   Sentence: 0      studies  NNS        O
# 1   Sentence: 0           on   IN        O
# 2   Sentence: 0    magnesium   NN        O
# 3   Sentence: 0            s   NN        O
# 4   Sentence: 0    mechanism   NN        O
# 5   Sentence: 0           of   IN        O
# 6   Sentence: 0       action   NN        O
# 7   Sentence: 0           in   IN        O
# 8   Sentence: 0    digitalis   NN    plant
# 9   Sentence: 0      induced  VBD        O
# 10  Sentence: 0  arrhythmias  NNS  disease
# 11  Sentence: 1          the   DT        O
# 12  Sentence: 1    mechanism   NN        O
# 13  Sentence: 1           by   IN        O
# 14  Sentence: 1        which  WDT        O
# 15  Sentence: 1    magnesium   NN        O
# 16  Sentence: 1      affects  VBZ        O
# 17  Sentence: 1    digitalis   RB    plant
# 18  Sentence: 1      induced   JJ        O
# 19  Sentence: 1  arrhythmias   NN  disease

# %% [markdown]
# # **CSV Dataset B-I-O**

# %%
pd.read_csv("/content/drive/MyDrive/Rearch_Dimas/NER-DATASET/csv_data/ner_biodataset.csv").head(20)
# Out:
#      Sentence #         Word  POS        Tag
# 0   Sentence: 0      studies  NNS          O
# 1   Sentence: 0           on   IN          O
# 2   Sentence: 0    magnesium   NN          O
# 3   Sentence: 0            s   NN          O
# 4   Sentence: 0    mechanism   NN          O
# 5   Sentence: 0           of   IN          O
# 6   Sentence: 0       action   NN          O
# 7   Sentence: 0           in   IN          O
# 8   Sentence: 0    digitalis   NN    B-plant
# 9   Sentence: 0      induced  VBD          O
# 10  Sentence: 0  arrhythmias  NNS  B-disease
# 11  Sentence: 1          the   DT          O
# 12  Sentence: 1    mechanism   NN          O
# 13  Sentence: 1           by   IN          O
# 14  Sentence: 1        which  WDT          O
# 15  Sentence: 1    magnesium   NN          O
# 16  Sentence: 1      affects  VBZ          O
# 17  Sentence: 1    digitalis   RB    B-plant
# 18  Sentence: 1      induced   JJ          O
# 19  Sentence: 1  arrhythmias   NN  B-disease
